# %% [markdown]
# ## NE 100/200M - Introduction to Nuclear Energy and Technology
# # Homework 5
# ##### Due September 30th, 2023
# All exercises are from the Murray & Holbert textbook and are numbered accordingly.

# %%
import math
import scipy.constants as constants

# %% [markdown]
# ### Exercise 18.6
#
# - (a) How many individual fuel pellets are there in the PWR reactor described in Section 18.4?
# - (b) Assuming a density of uranium oxide of 10 g/cm3, estimate the total mass of uranium and U-235 in the core in kilograms.
# - (c) Using Table 15.3 data, what is the initial fuel cost?

# %% [markdown]
# The equation for pellets per the amount of rods should be given by:
#
# $$N = \frac{H}{h} $$
#
# The equation for volume of a cylinder and mass per pellet:
#
# $$V = \pi r^2 h, m = V \rho $$

# %%
#This code is for part A
#We know from section 18.4 what the dimensions are for the PWR reactor.
H = 3.6e2 #in meters
h = 1.5 #in cm
N = H/h #this calculates the number of pellets per rod. But we still need to find the individual number of pellets.
#We know from section 18.4 that there are 200 rods in the assembly x 180 rods in the core
Rods = 200*180
#So the final number of individual rods is given by
Total_Pellets = N*Rods
print("(a) The total number of individual pellets in a PWR is {:.0f}".format(Total_Pellets))

#This code is for part B
r = 0.5 #in cm
V = math.pi*(r*r)*h
𝜌 = 10 #in g/cm^3
m = V*𝜌 
#This equation of m will give us the mass, but we have to subract the amount of UO2 from this value.
ratio = 238/270 #U ratio of UO2
#Now using the solution from part A, we can calculate this question:
Total_Mass_U = m*ratio*Total_Pellets/1e3
print("(b) The estimates total mass of U is {:.2f}kg".format(Total_Mass_U))
#Don't forget that the PWR is a 3% U-235 reactor, so we must multiply the previous answer by 0.03
Total_Mass_U235 = 0.03*Total_Mass_U
print("(b) The estimates total mass of U is {:.2f}kg".format(Total_Mass_U235))

#This code is for part C
#We know from table 15.3 that the cost per kilogram is $1025
cost = 1025
Initial_Cost = cost*Total_Mass_U
print("(c) The initial cost of the fuel will be ${:.2f}".format(Initial_Cost))
# Out:
# (a) The total number of individual pellets in a PWR is 8640000
# (b) The estimates total mass of U is 89723.89kg
# (b) The estimates total mass of U is 2691.72kg
# (c) The initial cost of the fuel will be $91966983.34

# %% [markdown]
# ### Exercise 18.7
#
# The core of a PWR contains 180 square fuel assemblies of length 4m, width 0.2m.
# - (a) Find the core volume and radius of an equivalent cylinder.
# - (b) If there are 200 fuel rods per assembly with pellets of diameter 0.9 cm, what is the approximate UO2 volume fraction of the core?

# %% [markdown]
# The equation for the volume of the assembly and the core, respectively, is given by:
#
# $$V_a = l b h, V_c = 180 V_a $$
#
# Then the area can be given by this equation, and we can rearrange to find R:
#
# $$A = \pi R^2 $$
#
# $$R = \sqrt{\frac{A}{\pi}} $$
#
# The area of a pellet can be given by:
#
# $$a = \pi R^2, where, R = \frac{d}{2}, so, a = \pi(\frac{d}{2})^2$$

# %%
#This code is for part A
l = 4 #in meters
b = 0.2 #in meters
h = 0.2 #in meters
V_a = l*b*h
V_c = 180*V_a
print("(a) The volume of the equivalent cylinder is {:.1f}m".format(V_c))
#Because we know b and h, we can calculate the value of the area:
Area = 180*b*h
#Now that we have the area, we can calculate for R
R = math.sqrt(Area/math.pi)
print("(a) The radius of this equivalent cylinder is {:.2f}m".format(R))

#This code is for part B
d = 0.9 #given in question and in cm units
a_assembly = 200*math.pi*((d/2)*(d/2))
a_core = (180*a_assembly)/1e2
ratio = (a_core/Area)/1e2
print("(b) The approximate volume fraction of the core is {:.2f}".format(ratio))
# Out:
# (a) The volume of the equivalent cylinder is 28.8m
# (a) The radius of this equivalent cylinder is 1.51m
# (b) The approximate volume fraction of the core is 0.32

# %% [markdown]
# ### Exercise 18.9
#
# Over the course of 3 years, a nuclear unit was shut down twice for refueling outages lasting
# 32 and 45 days, respectively, but was otherwise operating at full power. Determine the
# capacity factor for this 3-year period.

# %% [markdown]
# The equation for the capacity factor is given by:
#
# $$CF = \int_{0}^{T} \frac{P(t) \,dt}{P_e T}$$
#
# $$CF = [\frac{(T-t) P_e}{T P_e}]$$
#
# $$CF = \frac{(T-t)}{T}$$

# %%
T = 3*365
t = 32+45
CF = (T-t)/T
print("The capacity factor for this 3-year period is {:.2f}".format(CF))
# Out:
# The capacity factor for this 3-year period is 0.93

# %% [markdown]
# ### Exercise 18.10
# Compute a predicted core lifetime for the BWR of Table 18.4.

# %% [markdown]
# For the lifetime of a BWR, the equation is:
#
# $$T = \frac{B m_u}{Q_R}$$

# %%
B = 28000 #Fuel burnup in units of MWD per MTU
m_u = 138000 #Mass of the fuel in kilograms
Q_R = 3600*(1e3) #in units of kilograms per MT
T = (B*m_u)/Q_R
print("The predicted core lifetime of a BWR is {:.2f} days".format(T))
# Out:
# The predicted core lifetime of a BWR is 1073.33 days

# %% [markdown]
# ### Exercise 18.11
# Using data from Table 18.4, estimate the number of fuel rods in
# - (a) the PWR
# - (b) the BWR

# %% [markdown]
# The number of fuel rods in a reactor can also be given by the equation:
#
# $$N_R = \frac{Q_R}{q' H}$$
#
# Where Q_R is the reactor's power output, q' is the power per unit length, and H is the core's height.

# %%
#All numbers can be gotten from Table 18.4

#This code is for part A
Q_R = 3600*(1e3) #in MWt convert to kWt
q_prime = 5.4 #in Wt/ft
H = 145*(1/12) #in inches converted to feet
N_R = Q_R/(q_prime*H)
print("(a) The number of fuel rods in a PWR is {:.0f}".format(N_R))

#This code is for part B
#The same process as part A can be used.
Q_R = 3600*(1e3) #in MWt convert to kWt
q_prime = 6.1 #in Wt/ft
H = 148*(1/12) #in inches converted to feet
N_R = Q_R/(q_prime*H)
print("(b) The number of fuel rods in a BWR is {:.0f}".format(N_R))
# Out:
# (a) The number of fuel rods in a PWR is 55172
# (b) The number of fuel rods in a BWR is 47851

# %% [markdown]
# ### Excercise 24.3
# Many different energy units are found in the literature. Some of the useful equivalences are:
# - 1 bbl (oil) = $5.8 \times 10^6$ Btu
# - 1 quad = $10^{15}$ Btu
# - 1 Q = $10^{18}$ Btu
# - 1 exajoule (EJ) = $10^{18}$ J
#
# (a) found out how many barrels (bbl) of oil per day it takes to yield 1 GW of heat power.
# [you will need the eqn $P_{th} = HV * V$ where $P_{th}$ is thermal power, HV is heating value, and V is the barrel/day volume -- I couldn't find it in the text]
# (b) Show that the quad and the EJ are almost the same.
# (c) How many quads and Q correspond to the world annual energy consumption of approximately 500 EJ?
# (d) How many decays of nuclei yeilding 1 MeV would be needed to produce 1 EJ?

# %%
#This code is for part A
HV = 5.8e6*1055 #for one bbl of oil
P_th = 8.64e4*(1e9)
V = P_th/HV
print("(a) The number of barrels of oil needed per day will be {:.0f}".format(V))

#This code is for part B
one_quad = 1e15 #in BTU
quad_to_J = 1e15*1055
J_to_EJ = quad_to_J/1e18
print("(b) A quad and an EJ are almost the same, as 1 quad is about {:.2f}EJ".format(J_to_EJ))

#This code is for part C
quads = 500/1.05 #500EJ divided by our value from part B
Qs = 500e18/1e18/1055
print(quads)
print(Qs)
print("(c) The corresponding numbers of quads is about 476.2 and the corresponding number of Q's is 0.474")

#This code is for part D
decay_constant = 1.602e-13
Energy_Yield = 1e18/decay_constant #in Joules/(Joules*MeV) = MeV
Energy = 1 #in MeV
decays = Energy_Yield/Energy
print("(d) The number of decayed nuclei is {:.2e}".format(decays))
# Out:
# (a) The number of barrels of oil needed per day will be 14120
# (b) A quad and an EJ are almost the same, as 1 quad is about 1.05EJ
# 476.19047619047615
# 0.47393364928909953
# (c) The corresponding numbers of quads is about 476.2 and the corresponding number of Q's is 0.474
# (d) The number of decayed nuclei is 6.24e+30

# %% [markdown]
# ### Exercise 24.8
# Using Table 24.4 (or Table 24.2 - 7th addition) and an assummed capacity factor of 95% and levelized annual fixed charge rate of 10%, calculate combined capital and O&M costs for (8th addition)
#
# - (a) coal-fired with carbon capture
# - (b) natural gas combined cycle
# - (c) biomass power plants
# - (d) Comment on how do your answers compare to the O&M costs for Nuclear stated in Example 18.2 or Exercise 18.4
#
# or (7th addition):
#
# - (a) coal-fired
# - (b) natural gas
# - (c) geothermal
# - (d) municipal solid waste power plants
# - (e) Comment on how do your answers compare to the O&M costs for Nuclear stated in Example 18.2 or Exercise 18.4
#
# If you are interested: to do the additional set of power plant types using the 7th addition table:
#
# ![v7_24-8-table.PNG](attachment:v7_24-8-table.PNG)

# %% [markdown]
# The equation for combined capital and O&M costs is given by:
#
# $$ e = \frac{F_B I + O\&M}{P_e CF (8760h/y)} + \frac{F_C}{\eta_{th}B} $$

# %%
#I will be calculating the 7th edition values fo parts a, b, c, and d, then commenting in part e.

#This code is for part A
F_B = 4724 #in $
I = 0.1 #in years^-1
OandM = 66.43 #in $/(kWe*y)^-1
P_eCF = 0.95
e_A = ((F_B*I + OandM)/(P_eCF*8760)) + 9.51/1000
print("(a) The combined capital and O&M for coal-fired is ${:.2f}/kWh".format(e_A))

#This code is for part B
F_B = 1023 #in $
I = 0.1 #in years^-1
OandM = 15.73 #in $/(kWe*y)^-1
P_eCF = 0.95
e_B = ((F_B*I + OandM)/(P_eCF*8760)) + 3.27/1000
print("(b) The combined capital and O&M for natural gas is ${:.2f}/kWh".format(e_B))

#This code is for part C
F_B = 6243 #in $
I = 0.1 #in years^-1
OandM = 132 #in $/(kWe*y)^-1
P_eCF = 0.95
e_A = ((F_B*I + OandM)/(P_eCF*8760))
print("(c) The combined capital and O&M for geothermal is ${:.2f}/kWh".format(e_A))

#This code is for part D
F_B = 8312 #in $
I = 0.1 #in years^-1
OandM = 392.82 #in (kWe*y)^-1
P_eCF = 0.95
e_A = ((F_B*I + OandM)/(P_eCF*8760)) + 8.75/1000
print("(d) The combined capital and O&M for municipal solid waste power plants is ${:.2f}/kWh".format(e_A))

#This is for part E
print("(e) The example we did in class (Exercise 18.4) had a cost of $0.11/kWh. In comparison to the rest, it is slightly above average when it comes to expenses.")
# Out:
# (a) The combined capital and O&M for coal-fired is $0.07/kWh
# (b) The combined capital and O&M for natural gas is $0.02/kWh
# (c) The combined capital and O&M for geothermal is $0.09/kWh
# (d) The combined capital and O&M for municipal solid waste power plants is $0.16/kWh
# (e) The example we did in class (Exercise 18.4) had a cost of $0.11/kWh. In comparison to the rest, it is slightly above average when it comes to expenses.

# %% [markdown]
# ### Exercise 24.9
# If the cost of gasoline is $\$4 / gal$, compute the annual gross value of the $H_2$ product from a 1000-MWt reactor with a 45% efficiency for hydrogen generation.

# %% [markdown]
# Thermal electric power is given by:
#
# $$Q_{th} = \epsilon Q_{Rx}$$
#
# Production output of the gas is given by:
#
# $$Production = \frac{Q_{th}}{\Delta H_C \rho_{gas}}$$
#
# The Gross Value should be the production output multiplied by the cost of the gasoline per gallon:
#
# $$Gross Value = Production X 4$$

# %%
Q_th = 0.45*1000
V = (Q_th*3.155e7)/(45*730*(3.79e-3))
Value = V*4
print("The total gross value of this H2 is ${:.2f}, or around $456.1 million dollars".format(Value))
# Out:
# The total gross value of this H2 is $456139082.66, or around $456.1 million dollars
