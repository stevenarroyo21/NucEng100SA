# %% [markdown]
# ## NE 100/200M - Introduction to Nuclear Energy and Technology
# # Homework 0
# ##### Due August 27, 2023
# All exercises are from the Murray & Holbert textbook and are numbered accordingly.

# %% [markdown]
# ### Exercise 1
# Create a new cell in Markdown (text) mode and type your name in bold.

# %% [markdown]
# ### Steven Aroyo

# %% [markdown]
# ### Exercise 2
# Create a new cell in code mode and define a variable and give it the value of 5.

# %%
#Creating a variable X
x = 5
print(x)
# Out:
# 5

# %% [markdown]
# ### Exercise 3 ###
#
# Insert an image of the nuclear fission process.

# %% [markdown]
# ![NucEngFission.jpg](attachment:NucEngFission.jpg)

# %% [markdown]
# ### Exercise 4 ###
# Re-name your notebook to include your name. Save and download your notebook or get a shareable link (make sure you have *viewable with link permissions*). Include this in the introductory survey (last question).

# %% [markdown]
# Alright sounds good!
